# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\justi\OneDrive\Documents\Career foundry\Data Immersion 6'

# %%
df_team = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'team_code.csv'), index_col = False)

# %%
df_team_recruit = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data',  'team_recruit.pkl'))

# %%
df_team.head()
# Out:
#        primary_key ncaa_team_state
# 0  2018, Air Force              CO
# 1  2019, Air Force              CO
# 2  2020, Air Force              CO
# 3  2021, Air Force              CO
# 4  2022, Air Force              CO

# %%
df_team_recruit.head()
# Out:
#        primary_key  freshman_year           name position     high_school  \
# 0  2018, Air Force           2018      Jace Bobo      OLB         Cy-Fair
# 1  2018, Air Force           2018  Malik Rodgers       WR    Shadow Creek
# 2  2018, Air Force           2018   Jaylen Jones        S  Alief Hastings
# 3  2018, Air Force           2018   Warren Bryan     DUAL          Damien
# 4  2018, Air Force           2018     Chris Kane       TE    San Clemente
#
#    rating  stars committed_to recruit_type height  ... ncaa_year   ncaa_team  \
# 0  0.7953      2    Air Force   HighSchool     73  ...      2018  Air Force
# 1  0.8065      3    Air Force   HighSchool     69  ...      2018  Air Force
# 2  0.8054      3    Air Force   HighSchool     73  ...      2018  Air Force
# 3  0.7792      2    Air Force   HighSchool     74  ...      2018  Air Force
# 4  0.8255      3    Air Force   HighSchool     77  ...      2018  Air Force
#
# ...

# %%
df_team_recruit.shape
# Out:
# (13003, 26)

# %%
df_merge = df_team_recruit.merge(df_team, on = 'primary_key', indicator = True).fillna('Na')

# %%
df_merge.shape
# Out:
# (13003, 28)

# %%
df_merge.head()
# Out:
#        primary_key  freshman_year           name position     high_school  \
# 0  2018, Air Force           2018      Jace Bobo      OLB         Cy-Fair
# 1  2018, Air Force           2018  Malik Rodgers       WR    Shadow Creek
# 2  2018, Air Force           2018   Jaylen Jones        S  Alief Hastings
# 3  2018, Air Force           2018   Warren Bryan     DUAL          Damien
# 4  2018, Air Force           2018     Chris Kane       TE    San Clemente
#
#    rating  stars committed_to recruit_type height  ... conference total_games  \
# 0  0.7953      2    Air Force   HighSchool     73  ...        MWC          12
# 1  0.8065      3    Air Force   HighSchool     69  ...        MWC          12
# 2  0.8054      3    Air Force   HighSchool     73  ...        MWC          12
# 3  0.7792      2    Air Force   HighSchool     74  ...        MWC          12
# 4  0.8255      3    Air Force   HighSchool     77  ...        MWC          12
#
# ...

# %%
df_merge = df_merge.drop(columns = ['_merge'])

# %%
df_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'team_recruit_state.pkl'))
